# %%
import pandas as pd
import seaborn as sns

# %%
datos = pd.read_csv('candidatos.csv')
datos.drop_duplicates(inplace=True)
columnas = datos.columns

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5299 entries, 0 to 28894
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Experiencia        5299 non-null   int64
#  1   Educación          5299 non-null   object
#  2   Área               5299 non-null   object
#  3   C# Unity           5299 non-null   int64
#  4   C++ Unreal Engine  5299 non-null   int64
#  5   Flutter            5299 non-null   int64
#  6   HTML               5299 non-null   int64
#  7   CSS                5299 non-null   int64
#  8   React              5299 non-null   int64
#  9   Angular            5299 non-null   int64
#  10  JavaScript         5299 non-null   int64
#  11  Java               5299 non-null   int64
#  12  Kotlin             5299 non-null   int64
#  13  Swift              5299 non-null   int64
#  14  Python             5299 non-null   int64
#  15  SQL                5299 non-null   int64
# ...

# %%
sns.countplot(datos["Aptitud"])
# Out:
# <Axes: xlabel='count', ylabel='Aptitud'>
